# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldPapaya/info256-applied-nlp/blob/main/5.classification/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dbamman/anlp25/blob/main/5.classification/Classification.ipynb)

# %% [markdown]
# This notebook explores feature engineering for text classification, training a regularized logistic regression model for the binary classification task of predicting a movie's genre.

# %%
import json
import operator
from collections import Counter

import nltk
import pandas as pd
from scipy import sparse
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from tqdm import tqdm

nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !wget https://github.com/dbamman/anlp25/raw/refs/heads/main/data/movie.metadata.tsv
# !wget https://github.com/dbamman/anlp25/raw/refs/heads/main/data/plot_summaries.txt
# Out:
# --2025-09-23 23:44:24--  https://github.com/dbamman/anlp25/raw/refs/heads/main/data/movie.metadata.tsv
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dbamman/anlp25/refs/heads/main/data/movie.metadata.tsv [following]
# --2025-09-23 23:44:24--  https://raw.githubusercontent.com/dbamman/anlp25/refs/heads/main/data/movie.metadata.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15038604 (14M) [text/plain]
# Saving to: ‘movie.metadata.tsv’
#
# movie.metadata.tsv  100%[===================>]  14.34M  --.-KB/s    in 0.1s
#
# 2025-09-23 23:44:25 (130 MB/s) - ‘movie.metadata.tsv’ saved [15038604/15038604]
#
# --2025-09-23 23:44:25--  https://github.com/dbamman/anlp25/raw/refs/heads/main/data/plot_summaries.txt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dbamman/anlp25/refs/heads/main/data/plot_summaries.txt [following]
# --2025-09-23 23:44:25--  https://raw.githubusercontent.com/dbamman/anlp25/refs/heads/main/data/plot_summaries.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75934033 (72M) [text/plain]
# Saving to: ‘plot_summaries.txt’
#
# plot_summaries.txt  100%[===================>]  72.42M   265MB/s    in 0.3s
#
# 2025-09-23 23:44:27 (265 MB/s) - ‘plot_summaries.txt’ saved [75934033/75934033]

# %% [markdown]
# Read movie metadata and return dictionary mapping genres to the set of movies that are tagged with that genre; print out the top 30 genres by frequency.

# %%
def read_metadata(metadata_filename):
    metadata = pd.read_csv(metadata_filename, sep="\t", names=["movie_id", "_", "title", "year", "box_office", "_1", "_2", "_3", "json_genres"])

    # JSON genre looks like: {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic thriller", "/m/09blyk": "Psychological thriller"}
    # Convert to ["Thriller", "Erotic thriller", "Psychological thriller"]
    metadata.loc[:, "genres"] = metadata.json_genres.apply(lambda x: list(json.loads(x).values()) if x is not None else [])
    # Explode so that each row has one genre
    movie_genres_metadata = metadata[["movie_id", "genres"]].set_index("movie_id").explode("genres")

    # map from genre -> set(movie_ids)
    genre_movie_map = {genre: set(movie_ids) for genre, movie_ids in movie_genres_metadata.groupby("genres").groups.items()}

    # print out the 30 most frequent genres
    genre_counts = sorted([(genre, len(movie_ids)) for genre, movie_ids in genre_movie_map.items()], key=lambda x: x[1], reverse=True)
    for genre, count in genre_counts[:30]:
        print(count, "\t", genre)

    return genre_movie_map

# %%
metadata = read_metadata("movie.metadata.tsv")
# Out:
# 31890 	 Drama
# 15609 	 Comedy
# 9747 	 Romance Film
# 8661 	 Black-and-white
# 8363 	 Thriller
# 8223 	 Action
# 7155 	 World cinema
# 6883 	 Short Film
# 6629 	 Indie
# 6601 	 Crime Fiction
# 4963 	 Horror
# 4935 	 Documentary
# 4728 	 Silent film
# 4692 	 Adventure
# 4556 	 Action/Adventure
# 4146 	 Family Film
# 3981 	 Musical
# 3677 	 Comedy film
# 3345 	 Romantic drama
# 3052 	 Mystery
# 3005 	 Animation
# 2855 	 Science Fiction
# 2630 	 Romantic comedy
# 2616 	 Fantasy
# 2531 	 War film
# 2156 	 Western
# 2108 	 Crime Thriller
# 2087 	 Japanese Movies
# 1742 	 Period piece
# 1678 	 Comedy-drama

# %% [markdown]
# Subset the metadata to just those movies that exclusively appear with one of two genres selected for binary classification.

# %%
def filter_for_genres(metadata, genre_a, genre_b):
    # get all movies in genre_a and not in genre_b
    # remember, our metadata is of type dict[str, set]
    # so we can use set difference
    genre_a_movies = metadata[genre_a] - metadata[genre_b]

    # get all movies in genre_b but not in genre_a
    genre_b_movies = metadata[genre_b] - metadata[genre_a]

    labels = {
        a_movie: 1 for a_movie in genre_a_movies
    }
    labels.update({
        b_movie: 0 for b_movie in genre_b_movies
    })

    return labels

# %%
genre1 = "Romantic comedy"
genre2 = "Science Fiction"

labels = filter_for_genres(metadata, genre1, genre2)

# %% [markdown]
# Read movie summary data and tokenize the descriptions of those movies that match for the two genres selected.  Return a list of tokenized summaries and a corresponding list of their binary labels.

# %%
def read_data(plot_filename, labels):

    summaries = pd.read_csv(plot_filename, sep="\t", names=["movie_id", "summary"])
    # insert label
    summaries.loc[:, "label"] = summaries.movie_id.apply(lambda x: labels[x] if x in labels else -1)
    summaries = summaries.set_index("movie_id")

    def tokenize_and_process(text):
        return nltk.word_tokenize(text.lower())

    X = []
    Y = []
    for summary in tqdm(summaries.itertuples(), total=len(summaries)):
        if summary.Index not in labels:
            continue
        X.append(tokenize_and_process(summary.summary))
        Y.append(labels[summary.Index])

    return X, Y

# %%
X, Y = read_data("plot_summaries.txt", labels)
# Out:
# 100%|██████████| 42303/42303 [00:11<00:00, 3820.56it/s]

# %% [markdown]
# Split the data into training and validation sets (hold out 20% of the data for evaluation).

# %%
trainX, devX, trainY, devY = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
def build_features(dataX, feature_functions):
    """ Featurize the data according to the list of parameter feature_functions.

    Each feature_fn takes in a list of tokens and outputs a dictionary mapping strings to numbers.
    """

    data = []
    for tokens in dataX:
        feats = {}

        for feature_fn in feature_functions:
            feats.update(feature_fn(tokens))

        data.append(feats)
    return data

# %%
def features_to_ids(data, feature_vocab):
    """
    Convert a dictionary of feature names to a sparse representation that we can
    fit in a scikit-learn model.  This is important because almost all feature
    values will be 0 for most documents (note: why?), and we don't want to save
    them all in memory.
    """
    new_data = sparse.lil_matrix((len(data), len(feature_vocab)))
    for idx, doc in enumerate(data):
        for f in doc:
            if f in feature_vocab:
                new_data[idx,feature_vocab[f]]=doc[f]
    return new_data

# %%
def create_vocab(data, top_n=None):
    """
    This helper function converts a dictionary of feature names to unique numerical ids.
    top_n limits the features to only the n most frequent features observed in the training data
    (in terms of the number of documents that contains it).
    """
    counts = Counter()
    for doc in data:
        for feat in doc:
            counts[feat] += 1

    feature_vocab = {}

    for idx, (k, v) in enumerate(counts.most_common(top_n)):
        feature_vocab[k] = idx

    return feature_vocab

# %%
def pipeline(trainX, devX, trainY, devY, feature_functions):

    """ This function evaluates a list of feature functions on the training/dev data arguments """

    trainX_feat = build_features(trainX, feature_functions)
    devX_feat = build_features(devX, feature_functions)

    # just create vocabulary from features in *training* data.
    feature_vocab = create_vocab(trainX_feat, top_n=100000)

    trainX_ids = features_to_ids(trainX_feat, feature_vocab)
    devX_ids = features_to_ids(devX_feat, feature_vocab)

    clf = linear_model.LogisticRegression(C=100, solver='lbfgs', penalty='l2', max_iter=10000)
    clf.fit(trainX_ids, trainY)
    print("Accuracy: %.3f" % clf.score(devX_ids, devY))

    return clf, feature_vocab

# %% [markdown]
# Let's create a simple dictionary-based feature: this feature value is set to 1 for a document whenever any word present that dictionary appears in that document (and 0 otherwise).

# %%
comedy_dictionary = set(["comedy", "love", "date"])
scifi_dictionary = set(["science", "ship", "alien"])

def dictionary_feature(tokens):
    feats = {}
    for word in tokens:
        if word in comedy_dictionary:
            feats["word_in_comedy_dictionary"]=1
        if word in scifi_dictionary:
            feats["word_in_scifi_dictionary"]=1
    return feats

# %%
features = [dictionary_feature]
clf, vocab = pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.735

# %% [markdown]
# Is this accuracy good or bad?  We need to contextualize this performance against some baseline. A simple one to use is a *majority class* classifier: for every document in the test data, let's just predict whatever class appears the most frequently in the training data.

# %%
def majority_class(trainY, devY):
    labelCounts = Counter()
    for label in trainY:
        labelCounts[label] += 1
    majority_class = labelCounts.most_common(1)[0][0]

    correct=0.
    for label in devY:
        if label == majority_class:
            correct += 1

    print("%s\t%.3f" % (majority_class, correct/len(devY)))

# %%
majority_class(trainY, devY)
# Out:
# 0	0.523

# %%
def unigram_feature(tokens):
    feats = {}
    for word in tokens:
        feats["UNIGRAM_%s" % word] = 1
    return feats

# %%
features = [unigram_feature]
clf, vocab = pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.959

# %% [markdown]
# Let's print out the top 10 features with the strongest weights for each class

# %%
def print_weights(clf, vocab, n=10):
    weights = clf.coef_[0]
    reverse_vocab = [None] * len(weights)
    for k in vocab:
        reverse_vocab[vocab[k]] = k

    for feature, weight in sorted(zip(reverse_vocab, weights), key=lambda x: x[1])[:n]:
        print("%.3f\t%s" % (weight, feature))

    print()

    for feature, weight in list(sorted(zip(reverse_vocab, weights), key=lambda x: x[1], reverse=True))[:n]:
        print("%.3f\t%s" % (weight, feature))

# %%
print_weights(clf, vocab, n=10)
# Out:
# -3.660	UNIGRAM_earth
# -3.237	UNIGRAM_scientist
# -2.691	UNIGRAM_alien
# -2.658	UNIGRAM_dr.
# -2.444	UNIGRAM_planet
# -2.419	UNIGRAM_world
# -2.198	UNIGRAM_space
# -1.964	UNIGRAM_mysterious
# -1.867	UNIGRAM_future
# -1.853	UNIGRAM_kill
#
# 3.354	UNIGRAM_love
# 2.576	UNIGRAM_relationship
# 2.322	UNIGRAM_marriage
# 2.058	UNIGRAM_wedding
# 1.921	UNIGRAM_money
# 1.843	UNIGRAM_marry
# 1.787	UNIGRAM_she
# 1.776	UNIGRAM_married
# 1.655	UNIGRAM_men
# 1.544	UNIGRAM_sex

# %%
def your_awesome_feature(tokens):
    feats = {}
    for word in tokens:
        feats["UNIGRAM_%s" % word] = 1
    return feats

# %%
features=[your_awesome_feature]
pipeline(trainX, devX, trainY, devY, features)
# Out:
# Accuracy: 0.959
# (LogisticRegression(C=100, max_iter=10000),
#  {'UNIGRAM_.': 0,
#   'UNIGRAM_a': 1,
#   'UNIGRAM_,': 2,
#   'UNIGRAM_the': 3,
#   'UNIGRAM_to': 4,
#   'UNIGRAM_and': 5,
#   'UNIGRAM_of': 6,
#   'UNIGRAM_in': 7,
#   'UNIGRAM_is': 8,
#   'UNIGRAM_with': 9,
#   'UNIGRAM_his': 10,
#   "UNIGRAM_'s": 11,
#   'UNIGRAM_that': 12,
#   'UNIGRAM_he': 13,
#   'UNIGRAM_for': 14,
#   'UNIGRAM_by': 15,
#   'UNIGRAM_on': 16,
#   'UNIGRAM_as': 17,
#   'UNIGRAM_who': 18,
#   'UNIGRAM_an': 19,
#   'UNIGRAM_but': 20,
#   'UNIGRAM_her': 21,
#   'UNIGRAM_from': 22,
#   'UNIGRAM_has': 23,
#   'UNIGRAM_him': 24,
#   'UNIGRAM_at': 25,
#   'UNIGRAM_they': 26,
#   'UNIGRAM_when': 27,
#   'UNIGRAM_are': 28,
#   'UNIGRAM_it': 29,
#   'UNIGRAM_their': 30,
#   'UNIGRAM_after': 31,
#   'UNIGRAM_she': 32,
#   'UNIGRAM_into': 33,
#   'UNIGRAM_out': 34,
#   'UNIGRAM_be': 35,
#   'UNIGRAM_up': 36,
#   "UNIGRAM_''": 37,
#   'UNIGRAM_``': 38,
#   'UNIGRAM_one': 39,
#   'UNIGRAM_not': 40,
#   'UNIGRAM_them': 41,
#   'UNIGRAM_while': 42,
#   'UNIGRAM_which': 43,
#   'UNIGRAM_have': 44,
#   'UNIGRAM_about': 45,
#   'UNIGRAM_back': 46,
#   'UNIGRAM_this': 47,
#   'UNIGRAM_all': 48,
#   'UNIGRAM_then': 49,
#   'UNIGRAM_two': 50,
#   'UNIGRAM_was': 51,
#   'UNIGRAM_where': 52,
#   'UNIGRAM_can': 53,
#   'UNIGRAM_only': 54,
#   'UNIGRAM_new': 55,
#   'UNIGRAM_will': 56,
#   'UNIGRAM_time': 57,
#   'UNIGRAM_been': 58,
#   'UNIGRAM_before': 59,
#   'UNIGRAM_other': 60,
#   'UNIGRAM_find': 61,
#   'UNIGRAM_being': 62,
#   'UNIGRAM_also': 63,
#   'UNIGRAM_however': 64,
#   'UNIGRAM_off': 65,
#   'UNIGRAM_finds': 66,
#   'UNIGRAM_love': 67,
#   'UNIGRAM_so': 68,
#   'UNIGRAM_get': 69,
#   'UNIGRAM_over': 70,
#   'UNIGRAM_life': 71,
#   'UNIGRAM_later': 72,
#   'UNIGRAM_had': 73,
#   'UNIGRAM_;': 74,
#   'UNIGRAM_film': 75,
#   'UNIGRAM_takes': 76,
#   'UNIGRAM_first': 77,
#   'UNIGRAM_man': 78,
#   'UNIGRAM_tells': 79,
#   'UNIGRAM_home': 80,
#   'UNIGRAM_there': 81,
#   'UNIGRAM_himself': 82,
#   'UNIGRAM_does': 83,
#   'UNIGRAM_through': 84,
#   'UNIGRAM_more': 85,
#   'UNIGRAM_help': 86,
#   'UNIGRAM_during': 87,
#   'UNIGRAM_go': 88,
#   'UNIGRAM_down': 89,
#   'UNIGRAM_take': 90,
#   'UNIGRAM_way': 91,
#   'UNIGRAM_tries': 92,
#   'UNIGRAM_begins': 93,
#   'UNIGRAM_just': 94,
#   'UNIGRAM_make': 95,
#   'UNIGRAM_now': 96,
#   'UNIGRAM_away': 97,
#   'UNIGRAM_what': 98,
#   'UNIGRAM_goes': 99,
#   'UNIGRAM_another': 100,
#   'UNIGRAM_day': 101,
#   "UNIGRAM_'": 102,
#   'UNIGRAM_father': 103,
#   'UNIGRAM_:': 104,
#   'UNIGRAM_meanwhile': 105,
#   'UNIGRAM_no': 106,
#   'UNIGRAM_becomes': 107,
#   'UNIGRAM_own': 108,
#   'UNIGRAM_both': 109,
#   'UNIGRAM_friend': 110,
#   'UNIGRAM_some': 111,
#   'UNIGRAM_years': 112,
#   'UNIGRAM_night': 113,
#   'UNIGRAM_because': 114,
#   'UNIGRAM_eventually': 115,
#   'UNIGRAM_having': 116,
#   'UNIGRAM_young': 117,
#   "UNIGRAM_n't": 118,
#   'UNIGRAM_named': 119,
#   'UNIGRAM_decides': 120,
#   'UNIGRAM_gets': 121,
#   'UNIGRAM_soon': 122,
#   'UNIGRAM_leaves': 123,
#   'UNIGRAM_next': 124,
#   'UNIGRAM_meets': 125,
#   'UNIGRAM_end': 126,
#   'UNIGRAM_if': 127,
#   'UNIGRAM_return': 128,
#   'UNIGRAM_discovers': 129,
#   'UNIGRAM_world': 130,
#   'UNIGRAM_each': 131,
#   'UNIGRAM_its': 132,
#   'UNIGRAM_again': 133,
#   'UNIGRAM_together': 134,
#   'UNIGRAM_escape': 135,
#   'UNIGRAM_woman': 136,
#   'UNIGRAM_still': 137,
#   'UNIGRAM_finally': 138,
#   'UNIGRAM_do': 139,
#   'UNIGRAM_ends': 140,
#   'UNIGRAM_leave': 141,
#   'UNIGRAM_become': 142,
#   'UNIGRAM_returns': 143,
#   'UNIGRAM_or': 144,
#   'UNIGRAM_killed': 145,
#   'UNIGRAM_three': 146,
#   'UNIGRAM_makes': 147,
#   'UNIGRAM_friends': 148,
#   'UNIGRAM_comes': 149,
#   'UNIGRAM_people': 150,
#   'UNIGRAM_mother': 151,
#   'UNIGRAM_arrives': 152,
#   'UNIGRAM_work': 153,
#   'UNIGRAM_family': 154,
#   'UNIGRAM_see': 155,
#   'UNIGRAM_house': 156,
#   'UNIGRAM_how': 157,
#   'UNIGRAM_wife': 158,
#   'UNIGRAM_city': 159,
#   'UNIGRAM_until': 160,
#   'UNIGRAM_same': 161,
#   'UNIGRAM_between': 162,
#   'UNIGRAM_last': 163,
#   'UNIGRAM_asks': 164,
#   'UNIGRAM_death': 165,
#   'UNIGRAM_falls': 166,
#   'UNIGRAM_earth': 167,
#   'UNIGRAM_reveals': 168,
#   'UNIGRAM_would': 169,
#   'UNIGRAM_left': 170,
#   'UNIGRAM_well': 171,
#   'UNIGRAM_around': 172,
#   'UNIGRAM_story': 173,
#   'UNIGRAM_realizes': 174,
#   'UNIGRAM_along': 175,
#   'UNIGRAM_sees': 176,
#   'UNIGRAM_group': 177,
#   'UNIGRAM_attempts': 178,
#   'UNIGRAM_once': 179,
#   'UNIGRAM_meet': 180,
#   'UNIGRAM_wants': 181,
#   'UNIGRAM_even': 182,
#   'UNIGRAM_than': 183,
#   'UNIGRAM_relationship': 184,
#   'UNIGRAM_kill': 185,
#   'UNIGRAM_old': 186,
#   'UNIGRAM_men': 187,
#   'UNIGRAM_girl': 188,
#   'UNIGRAM_like': 189,
#   'UNIGRAM_turns': 190,
#   'UNIGRAM_too': 191,
#   'UNIGRAM_were': 192,
#   'UNIGRAM_using': 193,
#   'UNIGRAM_come': 194,
#   'UNIGRAM_use': 195,
#   'UNIGRAM_gives': 196,
#   'UNIGRAM_daughter': 197,
#   'UNIGRAM_against': 198,
#   'UNIGRAM_must': 199,
#   'UNIGRAM_much': 200,
#   'UNIGRAM_fight': 201,
#   'UNIGRAM_order': 202,
#   'UNIGRAM_set': 203,
#   'UNIGRAM_dr.': 204,
#   'UNIGRAM_leaving': 205,
#   'UNIGRAM_place': 206,
#   'UNIGRAM_under': 207,
#   'UNIGRAM_stop': 208,
#   'UNIGRAM_police': 209,
#   'UNIGRAM_head': 210,
#   'UNIGRAM_car': 211,
#   'UNIGRAM_trying': 212,
#   'UNIGRAM_discover': 213,
#   'UNIGRAM_though': 214,
#   'UNIGRAM_upon': 215,
#   'UNIGRAM_attempt': 216,
#   'UNIGRAM_several': 217,
#   'UNIGRAM_called': 218,
#   'UNIGRAM_job': 219,
#   'UNIGRAM_without': 220,
#   'UNIGRAM_son': 221,
#   'UNIGRAM_married': 222,
#   'UNIGRAM_taken': 223,
#   'UNIGRAM_[': 224,
#   'UNIGRAM_never': 225,
#   'UNIGRAM_learns': 226,
#   'UNIGRAM_since': 227,
#   'UNIGRAM_uses': 228,
#   'UNIGRAM_body': 229,
#   'UNIGRAM_movie': 230,
#   'UNIGRAM_dead': 231,
#   'UNIGRAM_runs': 232,
#   'UNIGRAM_going': 233,
#   'UNIGRAM_(': 234,
#   'UNIGRAM_try': 235,
#   'UNIGRAM_begin': 236,
#   'UNIGRAM_room': 237,
#   'UNIGRAM_shows': 238,
#   'UNIGRAM_starts': 239,
#   'UNIGRAM_instead': 240,
#   'UNIGRAM_agrees': 241,
#   'UNIGRAM_attack': 242,
#   'UNIGRAM_found': 243,
#   'UNIGRAM_town': 244,
#   'UNIGRAM_killing': 245,
#   'UNIGRAM_give': 246,
#   'UNIGRAM_herself': 247,
#   'UNIGRAM_including': 248,
#   'UNIGRAM_run': 249,
#   'UNIGRAM_lives': 250,
#   'UNIGRAM_human': 251,
#   'UNIGRAM_despite': 252,
#   'UNIGRAM_show': 253,
#   'UNIGRAM_appears': 254,
#   'UNIGRAM_local': 255,
#   'UNIGRAM_refuses': 256,
#   'UNIGRAM_says': 257,
#   'UNIGRAM_control': 258,
#   'UNIGRAM_able': 259,
#   'UNIGRAM_school': 260,
#   'UNIGRAM_party': 261,
#   'UNIGRAM_save': 262,
#   'UNIGRAM_living': 263,
#   'UNIGRAM_best': 264,
#   'UNIGRAM_explains': 265,
#   'UNIGRAM_whom': 266,
#   'UNIGRAM_long': 267,
#   'UNIGRAM_made': 268,
#   'UNIGRAM_plan': 269,
#   'UNIGRAM_most': 270,
#   'UNIGRAM_although': 271,
#   'UNIGRAM_very': 272,
#   'UNIGRAM_many': 273,
#   'UNIGRAM_live': 274,
#   'UNIGRAM_any': 275,
#   'UNIGRAM_working': 276,
#   'UNIGRAM_girlfriend': 277,
#   'UNIGRAM_scene': 278,
#   'UNIGRAM_taking': 279,
#   'UNIGRAM_kills': 280,
#   'UNIGRAM_manages': 281,
#   'UNIGRAM_inside': 282,
#   'UNIGRAM_making': 283,
#   'UNIGRAM_everyone': 284,
#   'UNIGRAM_destroy': 285,
#   'UNIGRAM_arrive': 286,
#   'UNIGRAM_secret': 287,
#   'UNIGRAM_sent': 288,
#   'UNIGRAM_calls': 289,
#   'UNIGRAM_due': 290,
#   'UNIGRAM_stay': 291,
#   'UNIGRAM_former': 292,
#   'UNIGRAM_part': 293,
#   'UNIGRAM_brother': 294,
#   'UNIGRAM_small': 295,
#   'UNIGRAM_turn': 296,
#   'UNIGRAM_works': 297,
#   'UNIGRAM_plans': 298,
#   'UNIGRAM_escapes': 299,
#   'UNIGRAM_outside': 300,
#   'UNIGRAM_behind': 301,
#   'UNIGRAM_breaks': 302,
#   'UNIGRAM_few': 303,
#   'UNIGRAM_keep': 304,
#   'UNIGRAM_power': 305,
#   'UNIGRAM_team': 306,
#   'UNIGRAM_ship': 307,
#   'UNIGRAM_forced': 308,
#   'UNIGRAM_could': 309,
#   'UNIGRAM_york': 310,
#   'UNIGRAM_marriage': 311,
#   'UNIGRAM_money': 312,
#   'UNIGRAM_planet': 313,
#   'UNIGRAM_fall': 314,
#   'UNIGRAM_women': 315,
#   'UNIGRAM_quickly': 316,
#   'UNIGRAM_final': 317,
#   'UNIGRAM_causing': 318,
#   'UNIGRAM_large': 319,
#   'UNIGRAM_-': 320,
#   'UNIGRAM_marry': 321,
#   'UNIGRAM_high': 322,
#   'UNIGRAM_know': 323,
#   'UNIGRAM_parents': 324,
#   'UNIGRAM_morning': 325,
#   'UNIGRAM_following': 326,
#   'UNIGRAM_things': 327,
#   'UNIGRAM_tell': 328,
#   'UNIGRAM_space': 329,
#   'UNIGRAM_themselves': 330,
#   'UNIGRAM_}': 331,
#   'UNIGRAM_start': 332,
#   'UNIGRAM_getting': 333,
#   'UNIGRAM_decide': 334,
#   'UNIGRAM_real': 335,
#   'UNIGRAM_husband': 336,
#   'UNIGRAM_good': 337,
#   'UNIGRAM_{': 338,
#   'UNIGRAM_used': 339,
#   'UNIGRAM_apartment': 340,
#   'UNIGRAM_actually': 341,
#   'UNIGRAM_believes': 342,
#   'UNIGRAM_year': 343,
#   'UNIGRAM_past': 344,
#   'UNIGRAM_call': 345,
#   'UNIGRAM_sends': 346,
#   'UNIGRAM_lost': 347,
#   'UNIGRAM_children': 348,
#   'UNIGRAM_revealed': 349,
#   'UNIGRAM_suddenly': 350,
#   'UNIGRAM_orders': 351,
#   'UNIGRAM_days': 352,
#   'UNIGRAM_alien': 353,
#   'UNIGRAM_unable': 354,
#   'UNIGRAM_couple': 355,
#   'UNIGRAM_boyfriend': 356,
#   'UNIGRAM_follows': 357,
#   'UNIGRAM_future': 358,
#   'UNIGRAM_known': 359,
#   'UNIGRAM_offers': 360,
#   'UNIGRAM_looking': 361,
#   'UNIGRAM_fire': 362,
#   'UNIGRAM_face': 363,
#   'UNIGRAM_whose': 364,
#   'UNIGRAM_battle': 365,
#   'UNIGRAM_others': 366,
#   'UNIGRAM_attacks': 367,
#   'UNIGRAM_destroyed': 368,
#   'UNIGRAM_wedding': 369,
#   'UNIGRAM_accidentally': 370,
#   'UNIGRAM_forces': 371,
#   'UNIGRAM_dies': 372,
#   'UNIGRAM_true': 373,
#   'UNIGRAM_company': 374,
#   'UNIGRAM_force': 375,
#   'UNIGRAM_sister': 376,
#   'UNIGRAM_boy': 377,
#   'UNIGRAM_telling': 378,
#   'UNIGRAM_alone': 379,
#   'UNIGRAM_did': 380,
#   'UNIGRAM_break': 381,
#   'UNIGRAM_seen': 382,
#   'UNIGRAM_put': 383,
#   'UNIGRAM_states': 384,
#   'UNIGRAM_hand': 385,
#   'UNIGRAM_date': 386,
#   'UNIGRAM_second': 387,
#   'UNIGRAM_plot': 388,
#   'UNIGRAM_such': 389,
#   'UNIGRAM_meeting': 390,
#   'UNIGRAM_hospital': 391,
#   'UNIGRAM_rescue': 392,
#   'UNIGRAM_name': 393,
#   'UNIGRAM_immediately': 394,
#   'UNIGRAM_bring': 395,
#   'UNIGRAM_enough': 396,
#   'UNIGRAM_american': 397,
#   'UNIGRAM_scientist': 398,
#   'UNIGRAM_station': 399,
#   'UNIGRAM_something': 400,
#   'UNIGRAM_child': 401,
#   'UNIGRAM_war': 402,
#   'UNIGRAM_attacked': 403,
#   'UNIGRAM_near': 404,
#   'UNIGRAM_should': 405,
#   'UNIGRAM_leads': 406,
#   'UNIGRAM_believe': 407,
#   'UNIGRAM_knows': 408,
#   'UNIGRAM_little': 409,
#   'UNIGRAM_rest': 410,
#   'UNIGRAM_kiss': 411,
#   'UNIGRAM_government': 412,
#   'UNIGRAM_process': 413,
#   'UNIGRAM_continues': 414,
#   'UNIGRAM_news': 415,
#   'UNIGRAM_sex': 416,
#   'UNIGRAM_crew': 417,
#   'UNIGRAM_across': 418,
#   'UNIGRAM_doctor': 419,
#   'UNIGRAM_given': 420,
#   'UNIGRAM_want': 421,
#   'UNIGRAM_nearby': 422,
#   'UNIGRAM_fact': 423,
#   'UNIGRAM_may': 424,
#   'UNIGRAM_building': 425,
#   'UNIGRAM_seeing': 426,
#   'UNIGRAM_causes': 427,
#   'UNIGRAM_alive': 428,
#   'UNIGRAM_earlier': 429,
#   'UNIGRAM_free': 430,
#   'UNIGRAM_form': 431,
#   'UNIGRAM_shot': 432,
#   'UNIGRAM_these': 433,
#   'UNIGRAM_search': 434,
#   'UNIGRAM_captured': 435,
#   'UNIGRAM_learn': 436,
#   'UNIGRAM_already': 437,
#   'UNIGRAM_loves': 438,
#   'UNIGRAM_heart': 439,
#   'UNIGRAM_visit': 440,
#   'UNIGRAM_right': 441,
#   'UNIGRAM_seems': 442,
#   'UNIGRAM_water': 443,
#   'UNIGRAM_events': 444,
#   'UNIGRAM_sets': 445,
#   'UNIGRAM_everything': 446,
#   'UNIGRAM_point': 447,
#   'UNIGRAM_led': 448,
#   'UNIGRAM_late': 449,
#   'UNIGRAM_convinces': 450,
#   'UNIGRAM_mind': 451,
#   'UNIGRAM_truth': 452,
#   'UNIGRAM_told': 453,
#   'UNIGRAM_feelings': 454,
#   'UNIGRAM_close': 455,
#   'UNIGRAM_let': 456,
#   'UNIGRAM_look': 457,
#   'UNIGRAM_open': 458,
#   'UNIGRAM_situation': 459,
#   'UNIGRAM_opens': 460,
#   'UNIGRAM_continue': 461,
#   'UNIGRAM_realize': 462,
#   'UNIGRAM_confronts': 463,
#   'UNIGRAM_beautiful': 464,
#   'UNIGRAM_every': 465,
#   'UNIGRAM_saying': 466,
#   'UNIGRAM_within': 467,
#   'UNIGRAM_mission': 468,
#   'UNIGRAM_thinks': 469,
#   'UNIGRAM_reach': 470,
#   'UNIGRAM_travel': 471,
#   'UNIGRAM_move': 472,
#   'UNIGRAM_mysterious': 473,
#   'UNIGRAM_successful': 474,
#   'UNIGRAM_four': 475,
#   'UNIGRAM_giant': 476,
#   'UNIGRAM_chance': 477,
#   'UNIGRAM_finding': 478,
#   'UNIGRAM_military': 479,
#   'UNIGRAM_needs': 480,
#   'UNIGRAM_side': 481,
#   'UNIGRAM_front': 482,
#   'UNIGRAM_dinner': 483,
#   'UNIGRAM_humans': 484,
#   'UNIGRAM_’': 485,
#   'UNIGRAM_s': 486,
#   'UNIGRAM_giving': 487,
#   'UNIGRAM_series': 488,
#   'UNIGRAM_change': 489,
#   'UNIGRAM_feels': 490,
#   'UNIGRAM_onto': 491,
#   'UNIGRAM_united': 492,
#   'UNIGRAM_door': 493,
#   'UNIGRAM_entire': 494,
#   'UNIGRAM_strange': 495,
#   'UNIGRAM_business': 496,
#   'UNIGRAM_destroys': 497,
#   'UNIGRAM_looks': 498,
#   'UNIGRAM_informs': 499,
#   'UNIGRAM_join': 500,
#   'UNIGRAM_person': 501,
#   'UNIGRAM_remaining': 502,
#   'UNIGRAM_really': 503,
#   'UNIGRAM_enters': 504,
#   'UNIGRAM_realizing': 505,
#   'UNIGRAM_different': 506,
#   'UNIGRAM_shoots': 507,
#   'UNIGRAM_talk': 508,
#   'UNIGRAM_towards': 509,
#   'UNIGRAM_died': 510,
#   'UNIGRAM_leader': 511,
#   'UNIGRAM_running': 512,
#   'UNIGRAM_happy': 513,
#   'UNIGRAM_race': 514,
#   'UNIGRAM_almost': 515,
#   'UNIGRAM_caught': 516,
#   'UNIGRAM_accepts': 517,
#   'UNIGRAM_nothing': 518,
#   'UNIGRAM_investigate': 519,
#   'UNIGRAM_encounter': 520,
#   'UNIGRAM_gun': 521,
#   'UNIGRAM_accident': 522,
#   'UNIGRAM_officer': 523,
#   'UNIGRAM_army': 524,
#   'UNIGRAM_machine': 525,
#   'UNIGRAM_brings': 526,
#   'UNIGRAM_trip': 527,
#   'UNIGRAM_you': 528,
#   'UNIGRAM_discovered': 529,
#   'UNIGRAM_convince': 530,
#   'UNIGRAM_great': 531,
#   'UNIGRAM_returning': 532,
#   'UNIGRAM_months': 533,
#   'UNIGRAM_leading': 534,
#   'UNIGRAM_initially': 535,
#   'UNIGRAM_rather': 536,
#   'UNIGRAM_romantic': 537,
#   'UNIGRAM_win': 538,
#   'UNIGRAM_further': 539,
#   'UNIGRAM_area': 540,
#   'UNIGRAM_captain': 541,
#   'UNIGRAM_island': 542,
#   'UNIGRAM_remains': 543,
#   'UNIGRAM_drive': 544,
#   'UNIGRAM_assistant': 545,
#   'UNIGRAM_land': 546,
#   'UNIGRAM_college': 547,
#   'UNIGRAM_state': 548,
#   'UNIGRAM_office': 549,
#   'UNIGRAM_hands': 550,
#   'UNIGRAM_&': 551,
#   'UNIGRAM_original': 552,
#   'UNIGRAM_falling': 553,
#   'UNIGRAM_die': 554,
#   'UNIGRAM_missing': 555,
#   'UNIGRAM_air': 556,
#   'UNIGRAM_agent': 557,
#   'UNIGRAM_star': 558,
#   'UNIGRAM_follow': 559,
#   'UNIGRAM_hotel': 560,
#   'UNIGRAM_gone': 561,
#   'UNIGRAM_creature': 562,
#   'UNIGRAM_ever': 563,
#   'UNIGRAM_visits': 564,
#   'UNIGRAM_crash': 565,
#   'UNIGRAM_always': 566,
#   'UNIGRAM_admits': 567,
#   'UNIGRAM_full': 568,
#   'UNIGRAM_becoming': 569,
#   'UNIGRAM_walks': 570,
#   'UNIGRAM_various': 571,
#   'UNIGRAM_why': 572,
#   'UNIGRAM_play': 573,
#   'UNIGRAM_big': 574,
#   'UNIGRAM_met': 575,
#   'UNIGRAM_members': 576,
#   'UNIGRAM_encounters': 577,
#   'UNIGRAM_student': 578,
#   'UNIGRAM_food': 579,
#   'UNIGRAM_number': 580,
#   'UNIGRAM_professor': 581,
#   'UNIGRAM_brought': 582,
#   'UNIGRAM_claims': 583,
#   'UNIGRAM_spend': 584,
#   'UNIGRAM_wealthy': 585,
#   'UNIGRAM_contact': 586,
#   'UNIGRAM_hit': 587,
#   'UNIGRAM_i': 588,
#   'UNIGRAM_moment': 589,
#   'UNIGRAM_john': 590,
#   'UNIGRAM_result': 591,
#   'UNIGRAM_pair': 592,
#   'UNIGRAM_destroying': 593,
#   'UNIGRAM_game': 594,
#   'UNIGRAM_phone': 595,
#   'UNIGRAM_created': 596,
#   'UNIGRAM_ground': 597,
#   'UNIGRAM_lead': 598,
#   'UNIGRAM_receives': 599,
#   'UNIGRAM_present': 600,
#   'UNIGRAM_helps': 601,
#   'UNIGRAM_powers': 602,
#   'UNIGRAM_waiting': 603,
#   'UNIGRAM_longer': 604,
#   'UNIGRAM_ca': 605,
#   'UNIGRAM_invites': 606,
#   'UNIGRAM_moves': 607,
#   'UNIGRAM_thinking': 608,
#   'UNIGRAM_boss': 609,
#   'UNIGRAM_care': 610,
#   'UNIGRAM_computer': 611,
#   'UNIGRAM_angry': 612,
#   'UNIGRAM_throws': 613,
#   'UNIGRAM_reveal': 614,
#   'UNIGRAM_black': 615,
#   'UNIGRAM_yet': 616,
#   'UNIGRAM_test': 617,
#   'UNIGRAM_shown': 618,
#   'UNIGRAM_apparently': 619,
#   'UNIGRAM_someone': 620,
#   'UNIGRAM_special': 621,
#   'UNIGRAM_steal': 622,
#   'UNIGRAM_knowing': 623,
#   'UNIGRAM_system': 624,
#   'UNIGRAM_top': 625,
#   'UNIGRAM_prevent': 626,
#   'UNIGRAM_coming': 627,
#   'UNIGRAM_affair': 628,
#   'UNIGRAM_!': 629,
#   'UNIGRAM_whole': 630,
#   'UNIGRAM_watch': 631,
#   'UNIGRAM_dying': 632,
#   'UNIGRAM_information': 633,
#   'UNIGRAM_completely': 634,
#   'UNIGRAM_radio': 635,
#   'UNIGRAM_?': 636,
#   'UNIGRAM_shortly': 637,
#   'UNIGRAM_train': 638,
#   'UNIGRAM_pregnant': 639,
#   'UNIGRAM_base': 640,
#   'UNIGRAM_crashes': 641,
#   'UNIGRAM_female': 642,
#   'UNIGRAM_demands': 643,
#   'UNIGRAM_deal': 644,
#   'UNIGRAM_heads': 645,
#   'UNIGRAM_act': 646,
#   'UNIGRAM_idea': 647,
#   'UNIGRAM_itself': 648,
#   'UNIGRAM_enter': 649,
#   'UNIGRAM_notices': 650,
#   'UNIGRAM_happened': 651,
#   'UNIGRAM_interest': 652,
#   'UNIGRAM_device': 653,
#   'UNIGRAM_create': 654,
#   'UNIGRAM_drives': 655,
#   'UNIGRAM_insists': 656,
#   'UNIGRAM_might': 657,
#   'UNIGRAM_board': 658,
#   'UNIGRAM_those': 659,
#   'UNIGRAM_wakes': 660,
#   'UNIGRAM_confesses': 661,
#   'UNIGRAM_course': 662,
#   'UNIGRAM_better': 663,
#   'UNIGRAM_problems': 664,
#   'UNIGRAM_unfortunately': 665,
#   'UNIGRAM_career': 666,
#   'UNIGRAM_security': 667,
#   'UNIGRAM_allows': 668,
#   'UNIGRAM_revealing': 669,
#   'UNIGRAM_dog': 670,
#   'UNIGRAM_owner': 671,
#   'UNIGRAM_scientists': 672,
#   'UNIGRAM_suggests': 673,
#   'UNIGRAM_wrong': 674,
#   'UNIGRAM_plays': 675,
#   'UNIGRAM_research': 676,
#   'UNIGRAM_chase': 677,
#   'UNIGRAM_attention': 678,
#   'UNIGRAM_television': 679,
#   'UNIGRAM_book': 680,
#   'UNIGRAM_baby': 681,
#   'UNIGRAM_arrested': 682,
#   'UNIGRAM_nuclear': 683,
#   'UNIGRAM_changes': 684,
#   'UNIGRAM_mr.': 685,
#   'UNIGRAM_doing': 686,
#   'UNIGRAM_unknown': 687,
#   'UNIGRAM_blood': 688,
#   'UNIGRAM_playing': 689,
#   'UNIGRAM_survivors': 690,
#   'UNIGRAM_believing': 691,
#   'UNIGRAM_times': 692,
#   'UNIGRAM_share': 693,
#   'UNIGRAM_short': 694,
#   'UNIGRAM_puts': 695,
#   'UNIGRAM_previous': 696,
#   'UNIGRAM_single': 697,
#   'UNIGRAM_anything': 698,
#   'UNIGRAM_thus': 699,
#   'UNIGRAM_light': 700,
#   'UNIGRAM_evening': 701,
#   'UNIGRAM_manage': 702,
#   'UNIGRAM_appear': 703,
#   'UNIGRAM_far': 704,
#   'UNIGRAM_hidden': 705,
#   'UNIGRAM_girls': 706,
#   'UNIGRAM_store': 707,
#   'UNIGRAM_shoot': 708,
#   'UNIGRAM_hiding': 709,
#   'UNIGRAM_flees': 710,
#   'UNIGRAM_among': 711,
#   'UNIGRAM_we': 712,
#   'UNIGRAM_aliens': 713,
#   'UNIGRAM_flee': 714,
#   'UNIGRAM_major': 715,
#   'UNIGRAM_five': 716,
#   'UNIGRAM_reaches': 717,
#   'UNIGRAM_dance': 718,
#   'UNIGRAM_bed': 719,
#   'UNIGRAM_stops': 720,
#   'UNIGRAM_plane': 721,
#   'UNIGRAM_threatens': 722,
#   'UNIGRAM_determined': 723,
#   'UNIGRAM_gang': 724,
#   'UNIGRAM_loses': 725,
#   'UNIGRAM_trouble': 726,
#   'UNIGRAM_bar': 727,
#   'UNIGRAM_complete': 728,
#   'UNIGRAM_shocked': 729,
#   'UNIGRAM_rich': 730,
#   'UNIGRAM_pilot': 731,
#   'UNIGRAM_saved': 732,
#   'UNIGRAM_younger': 733,
#   'UNIGRAM_fails': 734,
#   'UNIGRAM_trapped': 735,
#   'UNIGRAM_nearly': 736,
#   'UNIGRAM_project': 737,
#   'UNIGRAM_fighting': 738,
#   'UNIGRAM_need': 739,
#   'UNIGRAM_identity': 740,
#   'UNIGRAM_street': 741,
#   'UNIGRAM_explosion': 742,
#   'UNIGRAM_hears': 743,
#   'UNIGRAM_window': 744,
#   'UNIGRAM_cause': 745,
#   'UNIGRAM_early': 746,
#   'UNIGRAM_travels': 747,
#   'UNIGRAM_suicide': 748,
#   'UNIGRAM_middle': 749,
#   'UNIGRAM_restaurant': 750,
#   'UNIGRAM_underground': 751,
#   'UNIGRAM_secretly': 752,
#   'UNIGRAM_partner': 753,
#   'UNIGRAM_avoid': 754,
#   'UNIGRAM_surface': 755,
#   'UNIGRAM_case': 756,
#   'UNIGRAM_flying': 757,
#   'UNIGRAM_abandoned': 758,
#   'UNIGRAM_attracted': 759,
#   'UNIGRAM_reality': 760,
#   'UNIGRAM_successfully': 761,
#   'UNIGRAM_unconscious': 762,
#   'UNIGRAM_president': 763,
#   'UNIGRAM_exchange': 764,
#   'UNIGRAM_main': 765,
#   'UNIGRAM_involved': 766,
#   'UNIGRAM_got': 767,
#   'UNIGRAM_announces': 768,
#   'UNIGRAM_member': 769,
#   'UNIGRAM_watching': 770,
#   'UNIGRAM_lab': 771,
#   'UNIGRAM_lands': 772,
#   'UNIGRAM_thought': 773,
#   'UNIGRAM_fallen': 774,
#   'UNIGRAM_character': 775,
#   'UNIGRAM_ago': 776,
#   'UNIGRAM_hold': 777,
#   'UNIGRAM_broken': 778,
#   'UNIGRAM_normal': 779,
#   'UNIGRAM_revenge': 780,
#   'UNIGRAM_powerful': 781,
#   'UNIGRAM_older': 782,
#   'UNIGRAM_$': 783,
#   'UNIGRAM_beginning': 784,
#   'UNIGRAM_anyone': 785,
#   'UNIGRAM_showing': 786,
#   'UNIGRAM_romance': 787,
#   'UNIGRAM_flight': 788,
#   'UNIGRAM_fly': 789,
#   'UNIGRAM_evil': 790,
#   'UNIGRAM_knowledge': 791,
#   'UNIGRAM_reluctantly': 792,
#   'UNIGRAM_david': 793,
#   'UNIGRAM_energy': 794,
#   'UNIGRAM_hopes': 795,
#   'UNIGRAM_success': 796,
#   'UNIGRAM_attempting': 797,
#   'UNIGRAM_monster': 798,
#   'UNIGRAM_...': 799,
#   'UNIGRAM_pay': 800,
#   'UNIGRAM_dreams': 801,
#   'UNIGRAM_walk': 802,
#   'UNIGRAM_advice': 803,
#   'UNIGRAM_fellow': 804,
#   'UNIGRAM_prison': 805,
#   'UNIGRAM_happens': 806,
#   'UNIGRAM_keeps': 807,
#   'UNIGRAM_capture': 808,
#   'UNIGRAM_talking': 809,
#   'UNIGRAM_joins': 810,
#   'UNIGRAM_else': 811,
#   'UNIGRAM_sea': 812,
#   'UNIGRAM_truck': 813,
#   'UNIGRAM_murder': 814,
#   'UNIGRAM_weapons': 815,
#   'UNIGRAM_bomb': 816,
#   'UNIGRAM_location': 817,
#   'UNIGRAM_arriving': 818,
#   'UNIGRAM_catches': 819,
#   'UNIGRAM_upset': 820,
#   'UNIGRAM_lover': 821,
#   'UNIGRAM_survive': 822,
#   'UNIGRAM_hide': 823,
#   'UNIGRAM_returned': 824,
#   'UNIGRAM_chief': 825,
#   'UNIGRAM_stolen': 826,
#   'UNIGRAM_hope': 827,
#   'UNIGRAM_ready': 828,
#   'UNIGRAM_country': 829,
#   'UNIGRAM_london': 830,
#   'UNIGRAM_lose': 831,
#   'UNIGRAM_ride': 832,
#   'UNIGRAM_caused': 833,
#   'UNIGRAM_hours': 834,
#   'UNIGRAM_agree': 835,
#   'UNIGRAM_soldiers': 836,
#   'UNIGRAM_done': 837,
#   'UNIGRAM_possible': 838,
#   'UNIGRAM_characters': 839,
#   'UNIGRAM_saves': 840,
#   'UNIGRAM_rushes': 841,
#   'UNIGRAM_conversation': 842,
#   'UNIGRAM_support': 843,
#   'UNIGRAM_incident': 844,
#   'UNIGRAM_club': 845,
#   'UNIGRAM_arrival': 846,
#   'UNIGRAM_hoping': 847,
#   'UNIGRAM_offer': 848,
#   'UNIGRAM_clear': 849,
#   'UNIGRAM_slowly': 850,
#   'UNIGRAM_six': 851,
#   'UNIGRAM_seemingly': 852,
#   'UNIGRAM_throughout': 853,
#   'UNIGRAM_village': 854,
#   'UNIGRAM_huge': 855,
#   'UNIGRAM_means': 856,
#   'UNIGRAM_ask': 857,
#   'UNIGRAM_brain': 858,
#   'UNIGRAM_class': 859,
#   'UNIGRAM_public': 860,
#   'UNIGRAM_protect': 861,
#   'UNIGRAM_society': 862,
#   'UNIGRAM_think': 863,
#   'UNIGRAM_ultimately': 864,
#   'UNIGRAM_proposes': 865,
#   'UNIGRAM_weeks': 866,
#   'UNIGRAM_destruction': 867,
#   'UNIGRAM_massive': 868,
#   'UNIGRAM_turned': 869,
#   'UNIGRAM_reporter': 870,
#   'UNIGRAM_eyes': 871,
#   'UNIGRAM_perfect': 872,
#   'UNIGRAM_aboard': 873,
#   'UNIGRAM_learning': 874,
#   'UNIGRAM_thing': 875,
#   'UNIGRAM_flies': 876,
#   'UNIGRAM_walking': 877,
#   'UNIGRAM_promises': 878,
#   'UNIGRAM_based': 879,
#   'UNIGRAM_creatures': 880,
#   'UNIGRAM_whether': 881,
#   'UNIGRAM_king': 882,
#   'UNIGRAM_lets': 883,
#   'UNIGRAM_camera': 884,
#   'UNIGRAM_white': 885,
#   'UNIGRAM_general': 886,
#   'UNIGRAM_driving': 887,
#   'UNIGRAM_jealous': 888,
#   'UNIGRAM_dating': 889,
#   'UNIGRAM_engaged': 890,
#   'UNIGRAM_except': 891,
#   'UNIGRAM_wounded': 892,
#   'UNIGRAM_nature': 893,
#   'UNIGRAM_bad': 894,
#   'UNIGRAM_allowing': 895,
#   'UNIGRAM_accept': 896,
#   'UNIGRAM_park': 897,
#   'UNIGRAM_humanity': 898,
#   'UNIGRAM_send': 899,
#   'UNIGRAM_laboratory': 900,
#   'UNIGRAM_los': 901,
#   'UNIGRAM_beach': 902,
#   'UNIGRAM_pass': 903,
#   'UNIGRAM_sleep': 904,
#   'UNIGRAM_convinced': 905,
#   'UNIGRAM_track': 906,
#   'UNIGRAM_reason': 907,
#   'UNIGRAM_toward': 908,
#   'UNIGRAM_angeles': 909,
#   'UNIGRAM_unaware': 910,
#   'UNIGRAM_jack': 911,
#   'UNIGRAM_age': 912,
#   'UNIGRAM_desperate': 913,
#   'UNIGRAM_personal': 914,
#   'UNIGRAM_passes': 915,
#   'UNIGRAM_fired': 916,
#   'UNIGRAM_robot': 917,
#   'UNIGRAM_ending': 918,
#   'UNIGRAM_forcing': 919,
#   'UNIGRAM_bodies': 920,
#   'UNIGRAM_came': 921,
#   'UNIGRAM_hear': 922,
#   'UNIGRAM_journey': 923,
#   'UNIGRAM_recently': 924,
#   'UNIGRAM_private': 925,
#   'UNIGRAM_warns': 926,
#   'UNIGRAM_stand': 927,
#   'UNIGRAM_weapon': 928,
#   'UNIGRAM_appearance': 929,
#   'UNIGRAM_road': 930,
#   'UNIGRAM_guard': 931,
#   'UNIGRAM_ability': 932,
#   'UNIGRAM_develops': 933,
#   'UNIGRAM_problem': 934,
#   'UNIGRAM_tv': 935,
#   'UNIGRAM_program': 936,
#   'UNIGRAM_childhood': 937,
#   'UNIGRAM_message': 938,
#   'UNIGRAM_dream': 939,
#   'UNIGRAM_simply': 940,
#   'UNIGRAM_half': 941,
#   'UNIGRAM_music': 942,
#   'UNIGRAM_shop': 943,
#   'UNIGRAM_drunk': 944,
#   'UNIGRAM_watches': 945,
#   'UNIGRAM_rescued': 946,
#   'UNIGRAM_interested': 947,
#   'UNIGRAM_prove': 948,
#   'UNIGRAM_defeat': 949,
#   'UNIGRAM_confronted': 950,
#   'UNIGRAM_via': 951,
#   'UNIGRAM_cut': 952,
#   'UNIGRAM_opening': 953,
#   'UNIGRAM_moving': 954,
#   'UNIGRAM_happily': 955,
#   'UNIGRAM_explain': 956,
#   'UNIGRAM_safe': 957,
#   'UNIGRAM_say': 958,
#   'UNIGRAM_allow': 959,
#   'UNIGRAM_sexual': 960,
#   'UNIGRAM_line': 961,
#   'UNIGRAM_driver': 962,
#   'UNIGRAM_searching': 963,
#   'UNIGRAM_steals': 964,
#   'UNIGRAM_remain': 965,
#   'UNIGRAM_held': 966,
#   'UNIGRAM_asked': 967,
#   'UNIGRAM_fights': 968,
#   'UNIGRAM_deep': 969,
#   'UNIGRAM_holding': 970,
#   'UNIGRAM_awakens': 971,
#   'UNIGRAM_grabs': 972,
#   'UNIGRAM_surprise': 973,
#   'UNIGRAM_planning': 974,
#   'UNIGRAM_sky': 975,
#   'UNIGRAM_memory': 976,
#   'UNIGRAM_evidence': 977,
#   'UNIGRAM_aware': 978,
#   'UNIGRAM_existence': 979,
#   'UNIGRAM_prepares': 980,
#   'UNIGRAM_rock': 981,
#   'UNIGRAM_friendship': 982,
#   'UNIGRAM_safety': 983,
#   'UNIGRAM_pulls': 984,
#   'UNIGRAM_grows': 985,
#   'UNIGRAM_ocean': 986,
#   'UNIGRAM_hard': 987,
#   'UNIGRAM_failed': 988,
#   'UNIGRAM_video': 989,
#   'UNIGRAM_ways': 990,
#   'UNIGRAM_physical': 991,
#   'UNIGRAM_injured': 992,
#   'UNIGRAM_presence': 993,
#   'UNIGRAM_released': 994,
#   'UNIGRAM_attend': 995,
#   'UNIGRAM_airport': 996,
#   'UNIGRAM_grow': 997,
#   'UNIGRAM_report': 998,
#   'UNIGRAM_drops': 999,
#   ...})
